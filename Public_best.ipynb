# %%
#基本的なモジュール
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os, gc, re, time
import tqdm as tqdm
import warnings
pd.set_option("max_columns",None)
warnings.filterwarnings('ignore')

# %%
#前処理モジュール
from sklearn import preprocessing

# %%
#アルゴリズム
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
import lightgbm as lgb
import xgboost as xgb

#評価モジュール
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GroupKFold
from sklearn.model_selection import cross_val_score

#評価モジュール(スコア)
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

import pickle
import time
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials

# %% [markdown]
# # データ読み込み

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
#追加ファイルの編集したもの
add_data = pd.read_csv("land_price.csv")

# %% [markdown]
# # head

# %%
train.head(2)
# Out:
#    id      Type Region  MunicipalityCode Prefecture Municipality DistrictName  \
# 0   1  中古マンション等    NaN             13101        東京都         千代田区          飯田橋
# 1   2  中古マンション等    NaN             13101        東京都         千代田区          飯田橋
#
#   NearestStation TimeToNearestStation FloorPlan Area LandShape Frontage  \
# 0            飯田橋                    1      ２ＬＤＫ   55       NaN      NaN
# 1            飯田橋                    5        １Ｋ   20       NaN      NaN
#
#   TotalFloorArea BuildingYear Structure  Use Purpose Direction Classification  \
# 0            NaN        昭和59年       ＳＲＣ  NaN      住宅       NaN            NaN
# 1            NaN        平成15年        ＲＣ  NaN      住宅       NaN            NaN
#
#    Breadth CityPlanning  CoverageRatio  FloorAreaRatio      Period Renovation  \
# 0      NaN         商業地域           80.0           600.0  2017年第４四半期        改装済
# 1      NaN         商業地域           80.0           500.0  2017年第４四半期        未改装
#
#   Remarks     y
# 0     NaN  66.0
# 1     NaN  19.0

# %%
test.head(2)
# Out:
#    id      Type Region  MunicipalityCode Prefecture Municipality DistrictName  \
# 0   1  中古マンション等    NaN             13101        東京都         千代田区          飯田橋
# 1   2  中古マンション等    NaN             13101        東京都         千代田区          飯田橋
#
#   NearestStation TimeToNearestStation FloorPlan Area LandShape Frontage  \
# 0            飯田橋                    3      １ＬＤＫ   35       NaN      NaN
# 1            飯田橋                    4        １Ｋ   20       NaN      NaN
#
#   TotalFloorArea BuildingYear Structure  Use Purpose Direction Classification  \
# 0            NaN        昭和60年       ＳＲＣ   住宅      住宅       NaN            NaN
# 1            NaN        昭和57年       ＳＲＣ  NaN      住宅       NaN            NaN
#
#    Breadth CityPlanning  CoverageRatio  FloorAreaRatio      Period Renovation  \
# 0      NaN         商業地域           80.0           700.0  2018年第４四半期        未改装
# 1      NaN         商業地域           80.0           700.0  2018年第３四半期        未改装
#
#   Remarks
# 0     NaN
# 1     NaN

# %% [markdown]
# # 前処理

# %% [markdown]
# # データマージ

# %%
add_data = add_data[["Adress","H31_Price"]]
add_data = add_data.groupby("Adress")["H31_Price"].mean().reset_index()

# %%
train["Adress"] = train["Municipality"]+train["DistrictName"].fillna("")
train = pd.merge(train, add_data, on="Adress", how="left")
test["Adress"] = test["Municipality"]+test["DistrictName"].fillna("")
test = pd.merge(test, add_data, on="Adress", how="left")

# %% [markdown]
# ### category_process

# %%
for data in [train,test]:
    data[["year","quarter"]] = data["Period"].str.split("年",expand=True)

# %%
#cat変数
for col in ['Type', 'Municipality', 'quarter', 'DistrictName', 'NearestStation', 'CityPlanning', 'Region', 'LandShape',
            'Purpose', 'Direction', 'Classification', 'Renovation']:
    train[col] = train[col].fillna("N")
    test[col] = test[col].fillna("N")
    all_data = pd.concat([train[col], test[col]], axis=0, ignore_index=True).reset_index(drop=True)
    le = preprocessing.LabelEncoder()
    le.fit(all_data)
    train[col] = le.transform(train[col])
    test[col] = le.transform(test[col])
    train[col] = train[col].astype("category")
    test[col] = test[col].astype("category")

# %% [markdown]
# ### numerical

# %%
#とりあえず適当な値で埋める(欠損値はそのまま)
for data in [train,test]:
    #Area
    data.loc[data["Area"] == '2000㎡以上',"Area"] = '2100'
    data.loc[data["Area"] == '5000㎡以上',"Area"] = '5100'
    data["Area"] = data["Area"].astype(int)
    #TimeToNearestStation
    data.loc[data["TimeToNearestStation"] == '30分?60分',"TimeToNearestStation"] = 60
    data.loc[data["TimeToNearestStation"] == '1H?1H30',"TimeToNearestStation"] = 90
    data.loc[data["TimeToNearestStation"] == '1H30?2H',"TimeToNearestStation"] = 105
    data.loc[data["TimeToNearestStation"] == '2H?',"TimeToNearestStation"] = 120
    data.loc[data["TimeToNearestStation"].isnull() == True,"TimeToNearestStation"] = 1000
    data["TimeToNearestStation"] = data["TimeToNearestStation"].astype(int)
    data.loc[data["TimeToNearestStation"] == 1000,"TimeToNearestStation"] = np.nan
    #BuildingYear
    data["BuildingYear"] = data["BuildingYear"].fillna("昭和10年")
    data["BuildingYear"] = data["BuildingYear"].apply(lambda x: re.sub("戦前","昭和20年",x))
    data["syouwa_flag"] = data["BuildingYear"].apply(lambda x: 1 if "昭和" in x else 0)
    data["BuildingYear"] = data["BuildingYear"].apply(lambda x: re.sub("年|平成|昭和","",x))
    data["BuildingYear"] = data["BuildingYear"].astype(int)
    data.loc[data["syouwa_flag"] == 1,"BuildingYear"] -= 63
    data.loc[data["BuildingYear"] == -53,"BuildingYear"] = np.nan

# %%
#よくわからないがうまくいかなかったやつ
for data in [train,test]:
    #'FrontageTotal
    data.loc[data["Frontage"] == '50.0m以上', "Frontage"] = 55
    data.loc[data["Frontage"].isnull() == True, "Frontage"] = np.nan
    data["Frontage"] = data["Frontage"].astype(float)
    #TotalFloorArea
    data.loc[data["TotalFloorArea"] == '10m^2未満', "TotalFloorArea"] = 5
    data.loc[data["TotalFloorArea"] == '2000㎡以上', "TotalFloorArea"] = 2000
    data.loc[data["TotalFloorArea"].isnull() == True, "TotalFloorArea"] = np.nan
    data["TotalFloorArea"] = data["TotalFloorArea"].astype(float)

# %%
#feature_engineering
for data in [train,test]:
    data["log_price"] = np.log(data["Area"]*data["H31_Price"])
    data["price"] = data["Area"]*data["H31_Price"]/1000000
    data["H31_Price"] = data["H31_Price"]

# %% [markdown]
# # 訓練に突っ込むための処理

# %%
#Publicスコアではこれらのデータを落とした方がスコアは良かった。
train = train.drop([7198, 31498, 39578, 41402, 45428, 48111, 48657, 62445,
                    70789, 76144, 76360, 77939, 79209, 82113, 84399, 87031,
                    87247, 88639, 91690, 93234, 97266, 98266, 98573, 108115,
                    112505, 126270, 135390, 152007, 162170, 162489, 166184, 172434,
                    184612, 200975, 232290, 246517, 316066, 320210], axis=0).reset_index(drop=True)

# %%
drop_col = ["id","MunicipalityCode","Prefecture","FloorPlan","Remarks","Structure","Use","Period","year","syouwa_flag","Adress","price"]
test_id = test["id"]
target = train["y"]
train.drop(drop_col, axis=1, inplace=True)
train.drop("y", axis=1, inplace=True)

test.drop(drop_col, axis=1, inplace=True)
columns = train.columns

# %%
train.head()
# Out:
#   Type Region Municipality DistrictName NearestStation  TimeToNearestStation  \
# 0    0      0            9         1404            628                   1.0
# 1    0      0            9         1404            628                   5.0
# 2    0      0            9         1404            628                   3.0
# 3    0      0            9         1404            628                   5.0
# 4    2      2            9         1404            628                   3.0
#
#    Area LandShape  Frontage  TotalFloorArea  BuildingYear Purpose Direction  \
# 0    55         0       NaN             NaN          -4.0       3         0
# 1    20         0       NaN             NaN          15.0       3         0
# 2    45         0       NaN             NaN          24.0       1         0
# 3    20         0       NaN             NaN          15.0       3         0
# 4    80         1       6.8           330.0          -2.0       2         6
#
#   Classification  Breadth CityPlanning  CoverageRatio  FloorAreaRatio  \
# 0              0      NaN            1           80.0           600.0
# 1              0      NaN            1           80.0           500.0
# 2              0      NaN            1           80.0           500.0
# 3              0      NaN            1           80.0           500.0
# 4              2      8.0            1           80.0           500.0
#
#   Renovation  H31_Price quarter  log_price
# 0          1  3770000.0       3  19.149919
# 1          2  3770000.0       3  18.138318
# 2          2  3770000.0       2  18.949248
# 3          2  3770000.0       2  18.138318
# 4          0  3770000.0       1  19.524612

# %% [markdown]
# # 分析

# %%
#regression
params = {'objective': 'regression',
          'metric':'rmse',
          'max_depth': -1,
          'learning_rate': 0.01,
          "verbosity": 100,
          'seed': 777
         }

# %%
NFOLDS = 6
folds = StratifiedKFold(n_splits=NFOLDS, random_state=777)

#columns = feature
y_preds = np.zeros(test.shape[0])
y_oof = np.zeros(train.shape[0])
score = 0

feature_importance = pd.DataFrame()

feature_importance['feature'] = columns

start = time.time()
y_preds = np.zeros(test.shape[0])
y_oof = np.zeros(train.shape[0])
score = 0
splits = folds.split(train, train["Municipality"])
    
for fold_n, (train_index, valid_index) in enumerate(splits):
    fold_start = time.time()
    lg_train = lgb.Dataset(train.loc[train_index], label=target[train_index])
    lg_test = lgb.Dataset(train.loc[valid_index], label=target[valid_index])
    model = lgb.train(params, lg_train, 10000, valid_sets = [lg_train, lg_test], verbose_eval=1000, early_stopping_rounds=500)
    va_pred = model.predict(train.loc[valid_index])
    va_target = target[valid_index]
    feature_importance[f'fold_{fold_n + 1}'] = model.feature_importance()
        
    print(f"Fold {fold_n + 1} | RMSE: {np.sqrt(mean_squared_error(va_pred, va_target))}")
        
    score += np.sqrt(mean_squared_error(va_pred, va_target)) / NFOLDS
    y_oof[valid_index] = va_pred
    print("{:2.0f}分{:2.0f}秒".format((time.time()-fold_start)//60,(time.time()-fold_start)%60))
        
print("合計")
print("{:2.0f}分{:2.0f}秒".format((time.time()-start)//60,(time.time()-start)%60))
    

print(f"\nMean RMSE = {score}")
print(f"Out of folds RMSE = {np.sqrt(mean_squared_error(y_oof, target))}")
print()
# Out:
# Training until validation scores don't improve for 500 rounds
# [1000]	training's rmse: 66.7802	valid_1's rmse: 101.863
# [2000]	training's rmse: 50.6855	valid_1's rmse: 100.108
# [3000]	training's rmse: 42.4778	valid_1's rmse: 99.5458
# [4000]	training's rmse: 37.5937	valid_1's rmse: 99.3809
# [5000]	training's rmse: 33.9678	valid_1's rmse: 99.3793
# Early stopping, best iteration is:
# [4865]	training's rmse: 34.3611	valid_1's rmse: 99.3563
# Fold 1 | RMSE: 99.35633140544245
#  0分32秒
# Training until validation scores don't improve for 500 rounds
# [1000]	training's rmse: 66.8858	valid_1's rmse: 104.855
# [2000]	training's rmse: 50.8304	valid_1's rmse: 103.674
# [3000]	training's rmse: 42.8307	valid_1's rmse: 103.645
# Early stopping, best iteration is:
# [2528]	training's rmse: 46.0925	valid_1's rmse: 103.539
# Fold 2 | RMSE: 103.53876933703363
#  0分18秒
# Training until validation scores don't improve for 500 rounds
# Early stopping, best iteration is:
# [218]	training's rmse: 116.523	valid_1's rmse: 100.323
# Fold 3 | RMSE: 100.3233078833425
#  0分 5秒
# Training until validation scores don't improve for 500 rounds
# Early stopping, best iteration is:
# [402]	training's rmse: 90.5782	valid_1's rmse: 123.493
# Fold 4 | RMSE: 123.4928571695271
#  0分 6秒
# Training until validation scores don't improve for 500 rounds
# [1000]	training's rmse: 60.6826	valid_1's rmse: 139.958
# Early stopping, best iteration is:
# [1261]	training's rmse: 55.2663	valid_1's rmse: 139.909
# Fold 5 | RMSE: 139.90862547061462
#  0分11秒
# Training until validation scores don't improve for 500 rounds
# [1000]	training's rmse: 59.9361	valid_1's rmse: 146.536
# [2000]	training's rmse: 44.4565	valid_1's rmse: 145.731
# Early stopping, best iteration is:
# [2293]	training's rmse: 41.6192	valid_1's rmse: 145.542
# Fold 6 | RMSE: 145.54182652866712
#  0分17秒
# 合計
#  1分30秒
#
# Mean RMSE = 118.6936196324379
# Out of folds RMSE = 120.17809694468066

# %%
feature_importance['average'] = feature_importance[[f'fold_{fold_n + 1}' for fold_n in range(folds.n_splits)]].mean(axis=1)
feature_importance.to_csv('feature_importances.csv')

plt.figure(figsize=(16, 16))
sns.barplot(data=feature_importance.sort_values(by='average', ascending=False), x='average', y='feature');
plt.title('50 TOP feature importance over {} folds average'.format(folds.n_splits));

# %%
plt.scatter(y_oof, target)
plt.show()

# %% [markdown]
# # 全体を通して予測

# %%
submit = pd.DataFrame()
submit["id"] = test_id

# %%
lg_train = lgb.Dataset(train, label=target)
lg = lgb.train(params, lg_train, 2600)

# %%
predict = lg.predict(test)
submit["y"] = predict

# %%
#怪しい外れ値を変更
submit["y"].loc[33927] = 2714
submit["y"].loc[33941] = 4855

# %%
submit[submit["y"] < 0] = 0.01

# %%
submit.to_csv("submit85.csv",index=None)
